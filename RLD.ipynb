# %% [markdown]
# # **<u>RICE LEAF DISEASE PREDICTION<u/>**

# %% [markdown]
# ### **- Sidharth A**

# %% [markdown]
# # Problem statement

# %% [markdown]
# * To prepare a complete data analysis report on the given data.
#
# * To create a model which can classify the three major attacking diseases of rice plants like leaf blast, bacterial blight and brown spot.
#
# * Analyze various techniques like Data Augmentation etc and create a report on that.

# %% [markdown]
# ## Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Setting the constants

# %%
IMAGE_SIZE=256
BATCH_SIZE=10
channels=3
epochs = 100

# %% [markdown]
# ## Importing data into tensorflow dataset object

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
'Data',
shuffle=True,
image_size=(IMAGE_SIZE,IMAGE_SIZE),
batch_size=BATCH_SIZE)
# Out:
# Found 119 files belonging to 3 classes.

# %% [markdown]
# ## Domain analysis and Data Information

# %% [markdown]
# * Rice is one of the most important staple crops worldwide, providing sustenance to over half of the world's population. However, rice plants are vulnerable to several diseases that can severely impact the yield and quality of rice production. Some of the major rice diseases that affect rice plants include bacterial leaf blight, brown spot, and leaf smut.
#
# This dataset contains 120 jpg images of disease-infected rice leaves. The images are grouped into 3
# classes based on the type of disease. There are 40 images in each class.
#
# Classes :
#
# ● Leaf smut
# ● Brown spot
# ● Bacterial leaf blight
#
# * Leaf smut caused by the fungus Entyloma oryzae, is a relatively less common rice disease. The symptoms of leaf smut include the formation of small, round, and reddish-brown spots on the leaves. These spots later turn black and produce powdery spores. Although leaf smut does not usually cause significant yield losses, it can affect the quality of rice grains by reducing their weight and size .
#
# * Brown spot, caused by the fungus Cochliobolus miyabeanus, is another major rice disease that can cause significant yield losses. The disease is characterized by small, oval to elliptical spots on the leaves, which turn brown with a yellow halo. In severe cases, the spots can coalesce and cause the leaves to wither and die. Brown spot can also affect the panicles, leading to a reduction in grain quality and yield .
#
# * Bacterial leaf blight, caused by the bacterium Xanthomonas oryzae pv. oryzae, is a serious disease that can cause extensive damage to rice plants. The symptoms of bacterial leaf blight include water-soaked lesions on the leaves, which later turn brown and dry up. In severe cases, the disease can cause wilting and death of the plant, leading to a significant reduction in crop yield .

# %%
#class names
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial leaf blight', 'Brown spot', 'Leaf smut']

# %%
#total batches
len(dataset)
# Out:
# 12

# %%
for image_batch,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (10, 256, 256, 3)
# [2 0 0 1 1 1 0 0 0 2]

# %% [markdown]
# #### Observations
# * Each element in the dataset is a tuple. First element is a batch of 10 elements of images. Second element is a batch of 10 elements of class labels

# %% [markdown]
# ## Data visualization

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(4):
        ax = plt.subplot(2,2,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# ## Creating function to split the data for training, testing and validation.

# %% [markdown]
# Dividing dataset into 3 parts. Namely:
# * Training: Dataset to be used while training
# * Validation: Dataset to be tested against while training
# * Test: Dataset to be tested against after we trained a model

# %%
def get_partition_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=12)
    
    train_size = 8
    val_size = 2
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_partition_tf(dataset)

# %%
len(test_ds)
# Out:
# 2

# %% [markdown]
# ## Chache, shuffle and prefetch the dataset

# %% [markdown]
# ### Catche -
# * Instead of recomputing these values for each training iteration, the CNN can access and reuse them, which significantly speeds up training. This is especially helpful in CNNs where data augmentation or complex preprocessing is involved.
#
# ### Prefetch -
# * During CNN training, there are often periods where the model is computing gradients while waiting for the next batch of data to load. Prefetching allows us to start loading the next batch in the background while the model is training on the current batch. This overlapping of operations helps keep the GPU or CPU busy and can lead to faster training times.
#
# ### Shuffle -
# * If we feed the CNN consecutive batches of data that are highly correlated (e.g., all images of one class followed by another), the model may learn patterns based on this order, which can lead to poor generalization. Shuffling ensures that each batch contains a random mix of samples from different classes, making the training process more robust.

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Creating a Layer for Resizing and Normalization
#
# * Before we feed our images to network, we should be resizing it to the desired size. Moreover, to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 256). This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.
#
# * You might be thinking why do we need to resize (256,256) image to again (256,256). You are right we don't need to but this will be useful when we are done with the training and start using the model for predictions. At that time somone can supply an image that is not (256,256) and this layer will resize it

# %%
#preprocessing

resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# ## Data Augmentation
#
# * Data augmentation is a technique used to increase the size and diversity of a dataset by applying various transformations to the existing data. This technique has become an essential tool in computer vision and image processing tasks, such as object recognition and classification, due to its ability to enhance the generalization ability of machine learning models and prevent overfitting.
#
# * In the context of our rice leaf disease image classification project, data augmentation can play a crucial role in improving the performance and robustness of our model. By generating new images with different variations such as rotations, flips, zooms, and other transformations, we can increase the diversity of our dataset and provide our model with more examples to learn from, which can lead to better classification accuracy and robustness to variations in the real-world data.

# %%
data_aug = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal_and_vertical'),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
# Applying Data Augmentation on train dataset

train_ds = train_ds.map(
    lambda x, y: (data_aug(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Model Architecture
# * Here use a CNN coupled with a Softmax Activation in the output layerand also add the initial layers for Resizing, Normalization and Data Augmentation.

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,channels)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_aug,
    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D(2,2),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape=input_shape)

# %%
#architecture
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (10, 256, 256, 3)         0
#
#  sequential_4 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_5 (Conv2D)           (10, 254, 254, 32)        896
#
#  max_pooling2d_5 (MaxPooling  (10, 127, 127, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (10, 125, 125, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (10, 62, 62, 64)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (10, 60, 60, 64)          36928
#
#  max_pooling2d_7 (MaxPooling  (10, 30, 30, 64)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (10, 28, 28, 64)          36928
#
#  max_pooling2d_8 (MaxPooling  (10, 14, 14, 64)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (10, 12, 12, 32)          18464
#
#  max_pooling2d_9 (MaxPooling  (10, 6, 6, 32)           0
#  2D)
#
#  flatten_1 (Flatten)         (10, 1152)                0
#
#  dense_2 (Dense)             (10, 64)                  73792
#
#  dense_3 (Dense)             (10, 3)                   195
#
# =================================================================
# Total params: 185,699
# Trainable params: 185,699
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling the Model
# * We use adam Optimizer, SparseCategoricalCrossentropy for losses, accuracy as a metric.

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(train_ds,epochs=epochs,batch_size=BATCH_SIZE,verbose=1,
         validation_data=val_ds)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 10s 846ms/step - loss: 1.1166 - accuracy: 0.2658 - val_loss: 1.0382 - val_accuracy: 0.5500
# Epoch 2/100
# 8/8 [==============================] - 6s 750ms/step - loss: 1.1071 - accuracy: 0.3418 - val_loss: 1.0940 - val_accuracy: 0.5500
# Epoch 3/100
# 8/8 [==============================] - 6s 710ms/step - loss: 1.0984 - accuracy: 0.2911 - val_loss: 1.0911 - val_accuracy: 0.5500
# Epoch 4/100
# 8/8 [==============================] - 7s 807ms/step - loss: 1.0994 - accuracy: 0.3544 - val_loss: 1.0665 - val_accuracy: 0.5500
# Epoch 5/100
# 8/8 [==============================] - 6s 714ms/step - loss: 1.0964 - accuracy: 0.3544 - val_loss: 1.0685 - val_accuracy: 0.5500
# Epoch 6/100
# 8/8 [==============================] - 5s 664ms/step - loss: 1.0972 - accuracy: 0.3544 - val_loss: 1.0720 - val_accuracy: 0.5500
# Epoch 7/100
# 8/8 [==============================] - 5s 676ms/step - loss: 1.0913 - accuracy: 0.4430 - val_loss: 1.0944 - val_accuracy: 0.3000
# Epoch 8/100
# 8/8 [==============================] - 5s 657ms/step - loss: 1.0943 - accuracy: 0.4430 - val_loss: 1.0498 - val_accuracy: 0.6000
# Epoch 9/100
# 8/8 [==============================] - 5s 632ms/step - loss: 1.0921 - accuracy: 0.4051 - val_loss: 1.0883 - val_accuracy: 0.3000
# Epoch 10/100
# 8/8 [==============================] - 5s 628ms/step - loss: 1.0789 - accuracy: 0.4557 - val_loss: 1.0292 - val_accuracy: 0.6000
# Epoch 11/100
# 8/8 [==============================] - 5s 642ms/step - loss: 1.0733 - accuracy: 0.4557 - val_loss: 0.9705 - val_accuracy: 0.8500
# Epoch 12/100
# 8/8 [==============================] - 5s 634ms/step - loss: 1.0634 - accuracy: 0.4937 - val_loss: 0.9516 - val_accuracy: 0.6000
# Epoch 13/100
# 8/8 [==============================] - 5s 633ms/step - loss: 1.0404 - accuracy: 0.4430 - val_loss: 0.9619 - val_accuracy: 0.6500
# Epoch 14/100
# 8/8 [==============================] - 5s 652ms/step - loss: 1.0395 - accuracy: 0.4684 - val_loss: 0.9742 - val_accuracy: 0.6000
# Epoch 15/100
# 8/8 [==============================] - 5s 674ms/step - loss: 1.0019 - accuracy: 0.5190 - val_loss: 0.7142 - val_accuracy: 0.9000
# Epoch 16/100
# 8/8 [==============================] - 5s 636ms/step - loss: 0.8581 - accuracy: 0.6456 - val_loss: 0.5084 - val_accuracy: 0.8000
# Epoch 17/100
# 8/8 [==============================] - 5s 636ms/step - loss: 0.8134 - accuracy: 0.6329 - val_loss: 0.7489 - val_accuracy: 0.5000
# Epoch 18/100
# 8/8 [==============================] - 5s 642ms/step - loss: 0.9691 - accuracy: 0.4304 - val_loss: 0.9004 - val_accuracy: 0.4500
# Epoch 19/100
# 8/8 [==============================] - 5s 651ms/step - loss: 0.9094 - accuracy: 0.5190 - val_loss: 0.4073 - val_accuracy: 0.8000
# Epoch 20/100
# 8/8 [==============================] - 5s 630ms/step - loss: 0.7287 - accuracy: 0.6203 - val_loss: 0.4308 - val_accuracy: 0.8500
# Epoch 21/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.6708 - accuracy: 0.6835 - val_loss: 0.3583 - val_accuracy: 0.8500
# Epoch 22/100
# 8/8 [==============================] - 5s 630ms/step - loss: 0.7302 - accuracy: 0.6835 - val_loss: 0.3407 - val_accuracy: 0.8500
# Epoch 23/100
# 8/8 [==============================] - 5s 631ms/step - loss: 0.7070 - accuracy: 0.7089 - val_loss: 0.3084 - val_accuracy: 0.8500
# Epoch 24/100
# 8/8 [==============================] - 5s 637ms/step - loss: 0.7352 - accuracy: 0.7089 - val_loss: 0.3340 - val_accuracy: 0.9500
# Epoch 25/100
# 8/8 [==============================] - 5s 631ms/step - loss: 0.6628 - accuracy: 0.6962 - val_loss: 0.2282 - val_accuracy: 0.9500
# Epoch 26/100
# 8/8 [==============================] - 5s 638ms/step - loss: 0.6811 - accuracy: 0.6962 - val_loss: 0.3962 - val_accuracy: 0.8000
# Epoch 27/100
# 8/8 [==============================] - 5s 662ms/step - loss: 0.8315 - accuracy: 0.6203 - val_loss: 0.2464 - val_accuracy: 1.0000
# Epoch 28/100
# 8/8 [==============================] - 5s 639ms/step - loss: 0.6623 - accuracy: 0.7595 - val_loss: 0.2433 - val_accuracy: 1.0000
# Epoch 29/100
# 8/8 [==============================] - 5s 629ms/step - loss: 0.5349 - accuracy: 0.7848 - val_loss: 0.1530 - val_accuracy: 1.0000
# Epoch 30/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.5049 - accuracy: 0.7975 - val_loss: 0.1101 - val_accuracy: 1.0000
# Epoch 31/100
# 8/8 [==============================] - 5s 628ms/step - loss: 0.6285 - accuracy: 0.7468 - val_loss: 0.0999 - val_accuracy: 1.0000
# Epoch 32/100
# 8/8 [==============================] - 5s 634ms/step - loss: 0.5053 - accuracy: 0.8228 - val_loss: 0.1692 - val_accuracy: 0.9000
# Epoch 33/100
# 8/8 [==============================] - 5s 632ms/step - loss: 0.5468 - accuracy: 0.7215 - val_loss: 0.2075 - val_accuracy: 0.9500
# Epoch 34/100
# 8/8 [==============================] - 5s 659ms/step - loss: 0.7156 - accuracy: 0.7215 - val_loss: 0.3541 - val_accuracy: 0.8000
# Epoch 35/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.6316 - accuracy: 0.6962 - val_loss: 0.1701 - val_accuracy: 0.9500
# Epoch 36/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.6216 - accuracy: 0.7089 - val_loss: 0.2258 - val_accuracy: 0.9000
# Epoch 37/100
# 8/8 [==============================] - 5s 632ms/step - loss: 0.5941 - accuracy: 0.7595 - val_loss: 0.1436 - val_accuracy: 1.0000
# Epoch 38/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.5721 - accuracy: 0.7722 - val_loss: 0.3089 - val_accuracy: 0.9000
# Epoch 39/100
# 8/8 [==============================] - 5s 639ms/step - loss: 0.4670 - accuracy: 0.7595 - val_loss: 0.0914 - val_accuracy: 1.0000
# Epoch 40/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.5644 - accuracy: 0.7595 - val_loss: 0.1445 - val_accuracy: 1.0000
# Epoch 41/100
# 8/8 [==============================] - 5s 631ms/step - loss: 0.4277 - accuracy: 0.8101 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 42/100
# 8/8 [==============================] - 5s 641ms/step - loss: 0.4196 - accuracy: 0.7975 - val_loss: 0.0973 - val_accuracy: 0.9500
# Epoch 43/100
# 8/8 [==============================] - 5s 639ms/step - loss: 0.4378 - accuracy: 0.7975 - val_loss: 0.2918 - val_accuracy: 0.8000
# Epoch 44/100
# 8/8 [==============================] - 5s 651ms/step - loss: 0.6601 - accuracy: 0.7215 - val_loss: 0.2216 - val_accuracy: 0.9000
# Epoch 45/100
# 8/8 [==============================] - 5s 631ms/step - loss: 0.4853 - accuracy: 0.7848 - val_loss: 0.1973 - val_accuracy: 0.9500
# Epoch 46/100
# 8/8 [==============================] - 5s 630ms/step - loss: 0.5138 - accuracy: 0.8101 - val_loss: 0.0908 - val_accuracy: 1.0000
# Epoch 47/100
# 8/8 [==============================] - 5s 634ms/step - loss: 0.4129 - accuracy: 0.7848 - val_loss: 0.1570 - val_accuracy: 0.9500
# Epoch 48/100
# 8/8 [==============================] - 5s 628ms/step - loss: 0.4061 - accuracy: 0.8354 - val_loss: 0.1123 - val_accuracy: 0.9500
# Epoch 49/100
# 8/8 [==============================] - 5s 630ms/step - loss: 0.4125 - accuracy: 0.7848 - val_loss: 0.0857 - val_accuracy: 0.9500
# Epoch 50/100
# 8/8 [==============================] - 6s 704ms/step - loss: 0.3298 - accuracy: 0.8861 - val_loss: 0.0861 - val_accuracy: 0.9500
# Epoch 51/100
# 8/8 [==============================] - 7s 893ms/step - loss: 0.6497 - accuracy: 0.8101 - val_loss: 0.1662 - val_accuracy: 0.9500
# Epoch 52/100
# 8/8 [==============================] - 7s 810ms/step - loss: 0.5776 - accuracy: 0.7468 - val_loss: 0.1776 - val_accuracy: 0.9500
# Epoch 53/100
# 8/8 [==============================] - 6s 765ms/step - loss: 0.4603 - accuracy: 0.8608 - val_loss: 0.1301 - val_accuracy: 1.0000
# Epoch 54/100
# 8/8 [==============================] - 6s 726ms/step - loss: 0.4938 - accuracy: 0.7722 - val_loss: 0.0787 - val_accuracy: 1.0000
# Epoch 55/100
# 8/8 [==============================] - 6s 774ms/step - loss: 0.4815 - accuracy: 0.8101 - val_loss: 0.1432 - val_accuracy: 1.0000
# Epoch 56/100
# 8/8 [==============================] - 6s 746ms/step - loss: 0.3483 - accuracy: 0.8608 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 57/100
# 8/8 [==============================] - 6s 773ms/step - loss: 0.3769 - accuracy: 0.8481 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 58/100
# 8/8 [==============================] - 6s 759ms/step - loss: 0.4830 - accuracy: 0.8228 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 59/100
# 8/8 [==============================] - 6s 753ms/step - loss: 0.6094 - accuracy: 0.7595 - val_loss: 0.4128 - val_accuracy: 0.9000
# Epoch 60/100
# 8/8 [==============================] - 6s 724ms/step - loss: 0.5666 - accuracy: 0.7089 - val_loss: 0.0572 - val_accuracy: 1.0000
# Epoch 61/100
# 8/8 [==============================] - 6s 735ms/step - loss: 0.4977 - accuracy: 0.7595 - val_loss: 0.0824 - val_accuracy: 1.0000
# Epoch 62/100
# 8/8 [==============================] - 6s 787ms/step - loss: 0.4848 - accuracy: 0.7848 - val_loss: 0.0829 - val_accuracy: 1.0000
# Epoch 63/100
# 8/8 [==============================] - 6s 752ms/step - loss: 0.3284 - accuracy: 0.8734 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 64/100
# 8/8 [==============================] - 6s 747ms/step - loss: 0.3902 - accuracy: 0.8228 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 65/100
# 8/8 [==============================] - 6s 749ms/step - loss: 0.3909 - accuracy: 0.8228 - val_loss: 0.0546 - val_accuracy: 1.0000
# Epoch 66/100
# 8/8 [==============================] - 6s 763ms/step - loss: 0.3834 - accuracy: 0.8354 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 67/100
# 8/8 [==============================] - 6s 759ms/step - loss: 0.3319 - accuracy: 0.8734 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 68/100
# 8/8 [==============================] - 6s 721ms/step - loss: 0.3165 - accuracy: 0.8734 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 69/100
# 8/8 [==============================] - 6s 712ms/step - loss: 0.3035 - accuracy: 0.8861 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 70/100
# 8/8 [==============================] - 6s 707ms/step - loss: 0.2865 - accuracy: 0.9241 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 71/100
# 8/8 [==============================] - 6s 704ms/step - loss: 0.2979 - accuracy: 0.8987 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 72/100
# 8/8 [==============================] - 6s 684ms/step - loss: 0.2699 - accuracy: 0.8734 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 73/100
# 8/8 [==============================] - 6s 748ms/step - loss: 0.1983 - accuracy: 0.9367 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 74/100
# 8/8 [==============================] - 6s 745ms/step - loss: 0.1936 - accuracy: 0.9494 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 75/100
# 8/8 [==============================] - 6s 744ms/step - loss: 0.2173 - accuracy: 0.8987 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 76/100
# 8/8 [==============================] - 6s 709ms/step - loss: 0.2251 - accuracy: 0.9114 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 77/100
# 8/8 [==============================] - 6s 737ms/step - loss: 0.2016 - accuracy: 0.9241 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 78/100
# 8/8 [==============================] - 6s 720ms/step - loss: 0.1950 - accuracy: 0.9114 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 79/100
# 8/8 [==============================] - 5s 657ms/step - loss: 0.3079 - accuracy: 0.8481 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 80/100
# 8/8 [==============================] - 5s 668ms/step - loss: 0.5569 - accuracy: 0.7595 - val_loss: 0.1010 - val_accuracy: 0.9500
# Epoch 81/100
# 8/8 [==============================] - 6s 727ms/step - loss: 0.3254 - accuracy: 0.8861 - val_loss: 0.0959 - val_accuracy: 0.9500
# Epoch 82/100
# 8/8 [==============================] - 6s 711ms/step - loss: 0.3846 - accuracy: 0.8228 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 83/100
# 8/8 [==============================] - 6s 700ms/step - loss: 0.4586 - accuracy: 0.8228 - val_loss: 0.3023 - val_accuracy: 0.8500
# Epoch 84/100
# 8/8 [==============================] - 6s 731ms/step - loss: 0.3570 - accuracy: 0.8608 - val_loss: 0.0884 - val_accuracy: 0.9500
# Epoch 85/100
# 8/8 [==============================] - 6s 709ms/step - loss: 0.3520 - accuracy: 0.8608 - val_loss: 0.1276 - val_accuracy: 0.9500
# Epoch 86/100
# 8/8 [==============================] - 6s 729ms/step - loss: 0.2760 - accuracy: 0.8608 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 87/100
# 8/8 [==============================] - 6s 701ms/step - loss: 0.2854 - accuracy: 0.9114 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 88/100
# 8/8 [==============================] - 6s 707ms/step - loss: 0.2567 - accuracy: 0.8987 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 89/100
# 8/8 [==============================] - 6s 692ms/step - loss: 0.3249 - accuracy: 0.8354 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 90/100
# 8/8 [==============================] - 6s 685ms/step - loss: 0.3278 - accuracy: 0.8861 - val_loss: 0.0953 - val_accuracy: 0.9500
# Epoch 91/100
# 8/8 [==============================] - 6s 683ms/step - loss: 0.2170 - accuracy: 0.8987 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 92/100
# 8/8 [==============================] - 6s 709ms/step - loss: 0.2194 - accuracy: 0.9241 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 93/100
# 8/8 [==============================] - 6s 721ms/step - loss: 0.2252 - accuracy: 0.8861 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 94/100
# 8/8 [==============================] - 6s 711ms/step - loss: 0.2160 - accuracy: 0.9241 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 95/100
# 8/8 [==============================] - 5s 669ms/step - loss: 0.1933 - accuracy: 0.9241 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 96/100
# 8/8 [==============================] - 6s 729ms/step - loss: 0.1439 - accuracy: 0.9620 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 97/100
# 8/8 [==============================] - 6s 745ms/step - loss: 0.2187 - accuracy: 0.8987 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 98/100
# 8/8 [==============================] - 6s 704ms/step - loss: 0.2114 - accuracy: 0.8987 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 99/100
# 8/8 [==============================] - 6s 697ms/step - loss: 0.2532 - accuracy: 0.8734 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 100/100
# 8/8 [==============================] - 6s 704ms/step - loss: 0.2633 - accuracy: 0.8861 - val_loss: 0.0429 - val_accuracy: 1.0000

# %%
score = model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 111ms/step - loss: 0.1953 - accuracy: 0.9500

# %%
score
# Out:
# [0.19528929889202118, 0.949999988079071]

# %% [markdown]
# ## Plotting the Accuracy and Loss Curves

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 100, 'steps': 8}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Run prediction on a sample image

# %%
#prediction on sample
plt.figure(figsize=(10,10))
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Leaf smut
# 1/1 [==============================] - 0s 187ms/step
# predicted label: Leaf smut

# %% [markdown]
# ## Creating a function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# ## Prediction on few Sample Images

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [raw]
# #saving the model
#
# import os
# model_version=max([int(i) for i in os.listdir("../models") + [0]])+1
# model.save(f"../models/{model_version}")

# %% [markdown]
# # Summary
# * The project involved building a deep learning model to classify images of rice leaf disease. The dataset contained images from 3 type of rice leaf disease namely bacterial bligh, brown spot, and leaf smut. The project was divided into several steps, including data exploration, data preprocessing, building and training deep learning models, and evaluating model performance.
#
# * During data exploration, we analyzed the dataset and visualized the images to get a better understanding of the data. We observed that the dataset was balanced, with an equal number of images for rice leaf diseases. We also noticed that the images were of different sizes and needed to be resized to a uniform size before being used for training. We have rescaled them to uniform size of 256 X 256.
#
# * For data preprocessing, We have normalized the training dataset . We used Keras' ImageDataGenerator to generate augmented images to increase the size of the dataset and reduce overfitting. We also resized the images and divided them into training, validation, and testing sets.
#
# * We built  deep learning models by applying transfer learning technique,  we trained model on augmented datasets and evaluated their performance using accuracy, loss, and time taken per epoch.

# %% [markdown]
# # Problem Challenge -
# ### Limited amount of data:
# * One of the biggest challenges in the project was the limited amount of data available for training the models. We had only 119 images from 3 classes. This could lead to overfitting, where the model memorizes the training data and does not generalize well to new data. To deal with this challenge, data augmentation techniques were used to artificially increase the size of the dataset. This helped to improve the performance of the models and reduce overfitting.
#
# ### Complexity of deep learning models:
# * Deep learning models can be very complex and have a large number of parameters, which makes them difficult to train and optimize. To deal with this challenge, various techniques such as regularization, and early stopping were used to prevent overfitting and improve the performance of the models.
#
# ### Hardware limitations:
# * Deep learning models require a lot of computational resources, especially when training on large datasets. This can be a challenge if we don't have access to powerful hardware. To deal with this challenge, cloud computing services such as Google Colab were used to train the models, which provided access to powerful GPUs without the need for expensive hardware.
